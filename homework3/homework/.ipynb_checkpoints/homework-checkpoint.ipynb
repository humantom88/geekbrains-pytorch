# %% [markdown]
# # Практическое задание к уроку "Сегментация изображений (Pytorch)"

# %%
# !pip install segmentation_models_pytorch
# Out:
# Requirement already satisfied: segmentation_models_pytorch in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (0.1.3)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from segmentation_models_pytorch) (0.7.4)
# Requirement already satisfied: torchvision>=0.3.0 in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from segmentation_models_pytorch) (0.9.1)
# Requirement already satisfied: timm==0.3.2 in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from segmentation_models_pytorch) (0.3.2)
# Requirement already satisfied: efficientnet-pytorch==0.6.3 in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from segmentation_models_pytorch) (0.6.3)
# Requirement already satisfied: torch in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (1.8.1)
# Requirement already satisfied: tqdm in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (4.54.1)
# Requirement already satisfied: torch in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (1.8.1)
# Requirement already satisfied: munch in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (2.5.0)
# Requirement already satisfied: torchvision>=0.3.0 in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from segmentation_models_pytorch) (0.9.1)
# Requirement already satisfied: six in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from munch->pretrainedmodels==0.7.4->segmentation_models_pytorch) (1.15.0)
# Requirement already satisfied: torch in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (1.8.1)
# Requirement already satisfied: torchvision>=0.3.0 in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from segmentation_models_pytorch) (0.9.1)
# Requirement already satisfied: numpy in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from torch->efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (1.20.3)
# Requirement already satisfied: typing-extensions in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from torch->efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (3.10.0.0)
# Requirement already satisfied: numpy in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from torch->efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (1.20.3)
# Requirement already satisfied: torch in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (1.8.1)
# Requirement already satisfied: pillow>=4.1.1 in /Users/tombelov/opt/miniconda3/lib/python3.9/site-packages (from torchvision>=0.3.0->segmentation_models_pytorch) (8.2.0)

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import segmentation_models_pytorch as smp

# %%
DATA_ROOT = './data'
MASK_ROOT = './mask'
PROCESSED_MASK_ROOT = './mask_processed'
META_FILEPATH = './list.csv'

# %% [markdown]
# ### Загрузим мета информацию из файла

# %%
meta = pd.read_csv(META_FILEPATH)

# %%
meta
# Out:
#                 filename  width  height class  xmin  ymin  xmax  ymax  \
# 0      image00000001.jpg   1280     720  Lips   661   394   776   444
# 1      image00000002.jpg   1280     720  Lips   557   336   682   392
# 2      image00000003.jpg   1280     720  Lips   553   369   684   427
# 3      image00000004.jpg   1280     720  Lips   555   351   681   408
# 4      image00000005.jpg   1280     720  Lips   555   351   680   407
# ...                  ...    ...     ...   ...   ...   ...   ...   ...
# 28589  image00028590.jpg   1280     720  Lips   657   347   817   450
# 28590  image00028591.jpg   1280     720  Lips   713   325   884   388
# 28591  image00028592.jpg   1280     720  Lips   659   401   808   488
# 28592  image00028593.jpg   1280     720  Lips   689   334   839   431
# 28593  image00028594.jpg   1280     720  Lips   657   381   817   476
#
#                    mask
# 0      mask00000001.png
# 1      mask00000002.png
# 2      mask00000003.png
# 3      mask00000004.png
# 4      mask00000005.png
# ...                 ...
# 28589  mask00028590.png
# 28590  mask00028591.png
# 28591  mask00028592.png
# 28592  mask00028593.png
# 28593  mask00028594.png
#
# [28594 rows x 9 columns]

# %% [markdown]
# ### Просмотрим одно из изображений датасета

# %%
img = plt.imread(DATA_ROOT + '/image00000005.jpg')
plt.imshow(img[..., 0]);

# %% [markdown]
# ### И маску к нему

# %%
img = plt.imread(MASK_ROOT + '/mask00000005.png')
plt.imshow(img[..., 0]);

# %%
meta['class'].value_counts()
# Out:
# Lips    28594
# Name: class, dtype: int64

# %% [markdown]
# В датасете один класс, все объекты принадлежат этому классу

# %% [markdown]
# ### Оформим датасет pytorch

# %%
import os
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torch
from torch.nn import functional as F

# %%
labels = ['Unlabeled','Lips']

class LibsDataset(Dataset):
    def __init__(self, data, preprocessing=None):
        # Подаем наш подготовленный датафрейм
        self.data = data
        
        # Разделяем датафрейм на rgb картинки 
        self.image_arr = self.data.iloc[:,0]
        # и на сегментированные картинки
        self.label_arr = self.data.iloc[:,1]
        
        # Количество пар картинка-сегментация
        self.data_len = len(self.data.index)
        self.class_values = [0, 1]
        self.preprocessing = preprocessing
        
    def __getitem__(self, index):
        # Читаем картинку и сразу же представляем ее в виде numpy-массива 
        # размера 600х800 float-значений
        img = cv2.cvtColor(cv2.imread(os.path.join(DATA_ROOT, self.image_arr[index])), cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (256, 256))
        img = np.asarray(img).astype('float')
        
        if self.preprocessing:
            img = self.preprocessing(img)
            img = torch.as_tensor(img)
        else:
            # Нормализуем изображение в значениях [0, 1]
            img = torch.as_tensor(img) / 255.0
        img = img.permute(2,0,1)
        
        # считаем сегментированную картинку
        masks = []
        mask_image_path = os.path.join(MASK_ROOT, self.label_arr[index])
        mask = cv2.cvtColor(cv2.imread(mask_image_path), cv2.COLOR_BGR2RGB)
        
        cls_mask = np.where(mask == 1, 255, 0)
        cls_mask = cls_mask.astype('float')
        cls_mask = cv2.resize(cls_mask, (256, 256))

        masks.append(cls_mask[:,:,0] / 255)
            
        masks = torch.as_tensor(masks, dtype=torch.uint8)    
        
        return (img.float(), masks)

    def __len__(self):
        return self.data_len

# %%
df = meta.drop(columns=[    
    "width",
    "height",
    "class",
    "xmin",
    "ymin",
    "xmax",
    "ymax"
])
df
# Out:
#                 filename              mask
# 0      image00000001.jpg  mask00000001.png
# 1      image00000002.jpg  mask00000002.png
# 2      image00000003.jpg  mask00000003.png
# 3      image00000004.jpg  mask00000004.png
# 4      image00000005.jpg  mask00000005.png
# ...                  ...               ...
# 28589  image00028590.jpg  mask00028590.png
# 28590  image00028591.jpg  mask00028591.png
# 28591  image00028592.jpg  mask00028592.png
# 28592  image00028593.jpg  mask00028593.png
# 28593  image00028594.jpg  mask00028594.png
#
# [28594 rows x 2 columns]

# %% [markdown]
# ### === Этот блок выполняется один раз ===

# %%
# broken_mask_indexes = []
# for index, mask in enumerate(df['mask']):
#     try:
#         mask_image_path = mask_image_path = os.path.join(PROCESSED_MASK_ROOT, mask)
#         cv2.cvtColor(cv2.imread(mask_image_path), cv2.COLOR_BGR2RGB)
#     except Exception:
#         broken_mask_indexes.append(index)
# broken_mask_indexes

# %%
# from numpy import savetxt
# savetxt('broken_mask_indexes.csv', broken_mask_indexes, delimiter=',')

# %% [markdown]
# ### ==================================

# %%
from numpy import loadtxt
broken_mask_indexes = loadtxt('broken_mask_indexes.csv', delimiter=',')

# %%
for index in broken_mask_indexes:
    df = df.drop(index=index)

# %% [markdown]
# ### === Этот блок выполняется один раз ===

# %%
# mask_list = []
# for dirname, _, filenames in os.walk(MASK_ROOT):
#     for filename in filenames:
#         mask_list.append(filename)
# mask_list

# %%
# # Преобразование маски в монохромное изображение
# def mask_b(filename, save_path):
#     mask = cv2.imread(os.path.join(MASK_ROOT, filename), cv2.IMREAD_GRAYSCALE)
#     (thresh, mask_binary) = cv2.threshold(mask, 128, 255, cv2.THRESH_BINARY)
    
#     cv2.imwrite(os.path.join(save_path, filename), mask_binary)
#     return os.path.join(save_path, filename)

# %%
# for path in df['mask']:
#     mask_b(path, './mask_processed')

# %% [markdown]
# ### ==================================

# %%
dataset = LibsDataset(df)
img, masks = dataset[0]
fig, ax = plt.subplots(1, 2, figsize=(15, 7))
ax[0].imshow(img.permute(1, 2, 0))
ax[1].imshow(masks.permute(1, 2, 0))
plt.show()
# Out:
# <ipython-input-100-9ffb4b22f242>:44: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   masks = torch.as_tensor(masks, dtype=torch.uint8)

# %%
from sklearn.model_selection import train_test_split

# 70 % в тренировочную выборку, 30 - в тестовую
X_train, X_test = train_test_split(df, test_size=0.3)

# Упорядочиваем индексацию
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

# Оборачиваем каждую выборку в наш кастомный датасет
train_data = LibsDataset(X_train)
test_data = LibsDataset(X_test)

# %%
train_data_loader = DataLoader(
    train_data,
    batch_size=8,
    shuffle=True
)

# %%
import torch
import torch.nn as nn

def conv_block(in_channels,  out_channels):
    conv = nn.Sequential(
        nn.Conv2d(in_channels, out_channels, kernel_size=3),
        nn.ReLU(),
        nn.BatchNorm2d(num_features=out_channels),
        nn.Conv2d(out_channels, out_channels, kernel_size=3),
        nn.ReLU(),
        nn.BatchNorm2d(num_features=out_channels)
    )
    return conv

# %%
model = smp.Unet(classes=1)

# %% [markdown]
# ### Обучим модель

# %%
learning_rate = 0.001
epochs = 1

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
sample = (next(iter(train_data_loader)))
sample[1].shape
# Out:
# <ipython-input-100-9ffb4b22f242>:44: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   masks = torch.as_tensor(masks, dtype=torch.uint8)
# torch.Size([8, 1, 256, 256])

# %%
out = model(sample[0].to(device))
out.shape
# Out:
# torch.Size([8, 1, 256, 256])

# %%
plt.imshow(out[0][0].detach().cpu());

# %%
optimizer = torch.optim.Adam(model.parameters())

# %%
class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()

    def forward(self, logits, targets):
        smooth = 1
        num = targets.size(0)
        probs = logits
        m1 = probs.reshape(num, -1)
        m2 = targets.reshape(num, -1)
        intersection = (m1 * m2)

        score = (2. * intersection.sum(1) + smooth) / (m1.sum(1) + m2.sum(1) + smooth)
        score = 1 - (score.sum() / num)
        return score

# %%
total_steps = len(train_data_loader)
print(f"{epochs} epochs, {total_steps} total_steps per epoch")
# Out:
# 1 epochs, 2498 total_steps per epoch

# %%
criterion = DiceLoss()

# %%
#Импортируем библиотеку time для расчета, сколько времени у нас уходит на одну эпоху
import time

# запускаем главный тренировочный цикл
epoch_losses = []
for epoch in range(epochs):
    start_time = time.time()
    epoch_loss = []
    
    for batch_idx, (data, labels) in enumerate(train_data_loader):
        data, labels = data.to(device), labels.to(device)        
        
        optimizer.zero_grad()
        outputs = model(data)                

        loss = criterion(outputs, labels)
        
        loss.backward()
        optimizer.step()
        
        epoch_loss.append(loss.item())
        
        if batch_idx % 50 == 0:
            print(f'batch index : {batch_idx} | loss : {loss.item()}')

    print(f'Epoch {epoch+1}, loss: ', np.mean(epoch_loss))
    end_time = time.time()
    print(f'Spend time for 1 epoch: {start_time - end_time} sec')
    
    epoch_losses.append(epoch_loss)
# Out:
# <ipython-input-100-9ffb4b22f242>:44: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   masks = torch.as_tensor(masks, dtype=torch.uint8)
# batch index : 0 | loss : 1.0000190734863281
# batch index : 50 | loss : 0.9997369647026062
# batch index : 100 | loss : 0.999885618686676
# batch index : 150 | loss : 1.019273281097412
# batch index : 200 | loss : 0.999822199344635

# %%
save_model_path = './Unet_Model_dice_loss.pth'
